# %%
import h5py as h5
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# %matplotlib inline
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
#Manually changed file names to have pattern

path = '~/Desktop/IRI Yogurt/demos trips external 1_11 may13/'

for i in range(1,12):
    meta_df = pd.read_csv(path+'ads demo'+str(i)+'.csv')
    try:
        df = pd.concat([df,meta_df])
    except:
        df = meta_df

# %%
df.head()
# Out:
#   ALL_TVS  Age Group Applied to Female HH Age Group Applied to Household Head  \
# 0     NaN                               6                                 NaN
# 1     NaN                               5                                 NaN
# 2     NaN                               6                                 NaN
# 3     NaN                               6                                 NaN
# 4     NaN                               6                                 NaN
#
#    Age Group Applied to Male HH CABL_TVS COUNTY  Children Group Code  \
# 0                             6      NaN    NaN                    8
# 1                             7      NaN    NaN                    3
# 2                             6      NaN    NaN                    8
# 3                             6      NaN    NaN                    8
# 4                             6      NaN    NaN                    8
#
#   Combined Pre-Tax Income of HH  EXT_FACT  \
# 0                             3       NaN
# 1                             5       NaN
# 2                             8       NaN
# 3                             7       NaN
# 4                            10       NaN
#
#    Education Level Reached by Female HH            ...              \
# 0                                     3            ...
# 1                                     7            ...
# 2                                     6            ...
# 3                                     4            ...
# 4                                     4            ...
#
#   Occupation Code of Male HH  Panelist ID Panelist Type  RACE2  RACE3  \
# 0                         10      1100016             6    NaN    NaN
# 1                         11      1100032             0    NaN    NaN
# 2                         10      1100057             0    NaN    NaN
# 3                         10      1100156             6    NaN    NaN
# 4                          1      1100164             0    NaN    NaN
#
#    Type of Residential Possession Year  ZIPCODE  device_type  \
# 0                               2  1.0      NaN          NaN
# 1                               2  1.0      NaN          NaN
# 2                               2  1.0      NaN          NaN
# 3                               2  1.0      NaN          NaN
# 4                               2  1.0      NaN          NaN
#
#    market based upon zipcode
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 50 columns]

# %%
panel_df = pd.read_hdf('/home/sadat/Documents/DSE/Data/yogurt.h5', key='panel')
panel_df['Panelist ID']=panel_df['PANID']
panel_df.head()
# Out:
#         COLUPC  DOLLARS  IRI_KEY  MINUTE OUTLET    PANID  UNITS  WEEK  \
# 0  17047000300     0.99  1097117  5068.0    DK   3138826    1.0  1514
# 1  17047000302     0.89  1097117  2224.0    DK   3138826    1.0  1489
# 2  17047000650     0.89  1097117  6551.0    DK   3138826    1.0  1488
# 3  17047000650     2.97  1097117  6177.0    DK   3182048    3.0  1526
# 4  17047001372     1.49  1097117   973.0    DK   3184911    1.0  1495
#
#                             file  Panelist ID
# 0  yogurt_PANEL_DK_1479_1530.DAT      3138826
# 1  yogurt_PANEL_DK_1479_1530.DAT      3138826
# 2  yogurt_PANEL_DK_1479_1530.DAT      3138826
# 3  yogurt_PANEL_DK_1479_1530.DAT      3182048
# 4  yogurt_PANEL_DK_1479_1530.DAT      3184911

# %%
df = df.join(panel_df, on='Panelist ID', lsuffix='l',how='inner')

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [ALL_TVS, Age Group Applied to Female HH, Age Group Applied to Household Head, Age Group Applied to Male HH, CABL_TVS, COUNTY, Children Group Code, Combined Pre-Tax Income of HH, EXT_FACT, Education Level Reached by Female HH, Education Level Reached by Household Head, Education Level Reached by Male HH, FEM_SMOKE, FIPSCODE, Family Size, Female Working Hour Code, HH Head Race (RACE2), HH Head Race (RACE3), HH_AGE, HH_EDU, HH_LANG, HH_OCC, HH_RACE, HISP_CAT, HISP_FLAG, Hispanic Flag, Household Head Race, IRI Geography Number, Language, MALE_SMOKE, MICROWAVE, Male Working Hour Code, Marital Status, Microwave Owned by HH, Number of Cats, Number of Dogs, Number of TVs Hooked to Cable, Number of TVs Used by HH, Occupation Code of Female HH, Occupation Code of Household Head, Occupation Code of Male HH, Panelist IDl, Panelist Type, RACE2, RACE3, Type of Residential Possession, Year, ZIPCODE, device_type, market based upon zipcode, COLUPC, DOLLARS, IRI_KEY, MINUTE, OUTLET, PANID, UNITS, WEEK, file, Panelist ID]
# Index: []
#
# [0 rows x 60 columns]
