# %%
import h5py as h5
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from scipy.stats import ttest_ind
import calendar as cal
import seaborn as sns
import datetime as dt
# %matplotlib inline

# %%
path = '/home/sadat/Documents/DSE/Data/yogurt.h5'

# %% [markdown]
# ##Analyze yogurt.h5 structure

# %%
data = h5.File(path)

def printname(name):   
    print(name)

data.visit(printname)
# Out:
# delivery_stores
# delivery_stores/axis0
# delivery_stores/axis1
# delivery_stores/block0_items
# delivery_stores/block0_values
# delivery_stores/block1_items
# delivery_stores/block1_values
# delivery_stores/block2_items
# delivery_stores/block2_values
# demos
# demos/axis0
# demos/axis1
# demos/block0_items
# demos/block0_values
# demos/block1_items
# demos/block1_values
# demos/block2_items
# demos/block2_values
# drug
# drug/_i_table
# drug/_i_table/index
# drug/_i_table/index/abounds
# drug/_i_table/index/bounds
# drug/_i_table/index/indices
# drug/_i_table/index/indicesLR
# drug/_i_table/index/mbounds
# drug/_i_table/index/mranges
# drug/_i_table/index/ranges
# drug/_i_table/index/sorted
# drug/_i_table/index/sortedLR
# drug/_i_table/index/zbounds
# drug/table
# groc
# groc/_i_table
# groc/_i_table/index
# groc/_i_table/index/abounds
# groc/_i_table/index/bounds
# groc/_i_table/index/indices
# groc/_i_table/index/indicesLR
# groc/_i_table/index/mbounds
# groc/_i_table/index/mranges
# groc/_i_table/index/ranges
# groc/_i_table/index/sorted
# groc/_i_table/index/sortedLR
# groc/_i_table/index/zbounds
# groc/table
# panel
# panel/_i_table
# panel/_i_table/index
# panel/_i_table/index/abounds
# panel/_i_table/index/bounds
# panel/_i_table/index/indices
# panel/_i_table/index/indicesLR
# panel/_i_table/index/mbounds
# panel/_i_table/index/mranges
# panel/_i_table/index/ranges
# panel/_i_table/index/sorted
# panel/_i_table/index/sortedLR
# panel/_i_table/index/zbounds
# panel/table

# %%
data.close()

# %% [markdown]
# ##Panel data

# %%
df = pd.read_hdf(path, key='panel')

# %%
df.head()
# Out:
#         COLUPC  DOLLARS  IRI_KEY  MINUTE OUTLET    PANID  UNITS  WEEK  \
# 0  17047000300     0.99  1097117  5068.0    DK   3138826    1.0  1514
# 1  17047000302     0.89  1097117  2224.0    DK   3138826    1.0  1489
# 2  17047000650     0.89  1097117  6551.0    DK   3138826    1.0  1488
# 3  17047000650     2.97  1097117  6177.0    DK   3182048    3.0  1526
# 4  17047001372     1.49  1097117   973.0    DK   3184911    1.0  1495
#
#                             file
# 0  yogurt_PANEL_DK_1479_1530.DAT
# 1  yogurt_PANEL_DK_1479_1530.DAT
# 2  yogurt_PANEL_DK_1479_1530.DAT
# 3  yogurt_PANEL_DK_1479_1530.DAT
# 4  yogurt_PANEL_DK_1479_1530.DAT

# %% [markdown]
# ####Missing data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1609107 entries, 0 to 15
# Data columns (total 9 columns):
# COLUPC     1609107 non-null int64
# DOLLARS    1609107 non-null float64
# IRI_KEY    1609107 non-null int64
# MINUTE     520189 non-null float64
# OUTLET     1609107 non-null object
# PANID      1609107 non-null int64
# UNITS      1609107 non-null float64
# WEEK       1609107 non-null int64
# file       1609107 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 122.8+ MB

# %% [markdown]
# We see that MINUTE is missing. We will drop this and work with data after 2008.

# %%
df = df.dropna(axis=0)
df.head()
# Out:
#         COLUPC  DOLLARS  IRI_KEY  MINUTE OUTLET    PANID  UNITS  WEEK  \
# 0  17047000300     0.99  1097117  5068.0    DK   3138826    1.0  1514
# 1  17047000302     0.89  1097117  2224.0    DK   3138826    1.0  1489
# 2  17047000650     0.89  1097117  6551.0    DK   3138826    1.0  1488
# 3  17047000650     2.97  1097117  6177.0    DK   3182048    3.0  1526
# 4  17047001372     1.49  1097117   973.0    DK   3184911    1.0  1495
#
#                             file
# 0  yogurt_PANEL_DK_1479_1530.DAT
# 1  yogurt_PANEL_DK_1479_1530.DAT
# 2  yogurt_PANEL_DK_1479_1530.DAT
# 3  yogurt_PANEL_DK_1479_1530.DAT
# 4  yogurt_PANEL_DK_1479_1530.DAT

# %% [markdown]
# ####Sales by Outlet

# %%
df.groupby('OUTLET')['DOLLARS'].sum().plot(kind='bar', title='Sales by Outlet');

# %% [markdown]
# GK has significantly higher sales compared to other outlets.

# %% [markdown]
# ####Sales by time (MINUTE and WEEK)

# %%
def get_datetime(week, minute):
    week, minute = int(week), int(minute)
    # Reference orginal date is September 3, 1979
    ref_orginal = dt.date.toordinal(dt.date(1979, 9, 3))
    # Convert minutes to days, hours, minutes
    days, hours, mins = (minute / 1440), ((minute % 1440) / 60), ((minute % 1440) % 60)
    # Convert from ordinal.
    return dt.datetime.fromordinal(ref_orginal + (week - 1) * 7 + days).replace(
        hour=hours, minute=mins)

df = df.dropna(axis=0)
week = df['WEEK'].values
minute = df['MINUTE'].values
datetime = []

for w,m in zip(week,minute):
    datetime.append(get_datetime(w,m))

df['DATETIME']=datetime

# %%
df.head()
# Out:
#         COLUPC  DOLLARS  IRI_KEY  MINUTE OUTLET    PANID  UNITS  WEEK  \
# 0  17047000300     0.99  1097117  5068.0    DK   3138826    1.0  1514
# 1  17047000302     0.89  1097117  2224.0    DK   3138826    1.0  1489
# 2  17047000650     0.89  1097117  6551.0    DK   3138826    1.0  1488
# 3  17047000650     2.97  1097117  6177.0    DK   3182048    3.0  1526
# 4  17047001372     1.49  1097117   973.0    DK   3184911    1.0  1495
#
#                             file            DATETIME
# 0  yogurt_PANEL_DK_1479_1530.DAT 2008-09-04 12:28:00
# 1  yogurt_PANEL_DK_1479_1530.DAT 2008-03-11 13:04:00
# 2  yogurt_PANEL_DK_1479_1530.DAT 2008-03-07 13:11:00
# 3  yogurt_PANEL_DK_1479_1530.DAT 2008-11-28 06:57:00
# 4  yogurt_PANEL_DK_1479_1530.DAT 2008-04-21 16:13:00

# %% [markdown]
# Based on the spikes, we can tell that yogurt sales are higher during certain times of the day.
#
# Now analyzing based on Years:

# %%
plt.figure(figsize=(17,5));
df.groupby(df.DATETIME.dt.year)['DOLLARS'].sum().plot(kind='bar',title='Sales 2007-2012');

# %% [markdown]
# While there are spikes in sales of yogurt after 2008, there are no observable pattern. This might be caused by the dropping of NaNs. Hence we will drop values before 2008.

# %%
df = df[df.DATETIME.dt.year>2007]

plt.figure(figsize=(17,5));
df.groupby(df.DATETIME.dt.year)['DOLLARS'].sum().plot(kind='bar',title='Sales 2008-2012');

# %% [markdown]
# Now let's look at our data by Month, Day and Hour:

# %%
product_panel = df
product_panel['MINUTE'].dropna(inplace=True)

# Setup figure
gs = plt.GridSpec(2, 2, wspace=0.2)
fig = plt.figure(figsize=(16, 10))

ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[1, :])

# Sales analysis in each month

product_sales_hour = product_panel.groupby(
    product_panel.DATETIME.dt.month)['DOLLARS'].sum()
product_sales_hour.plot(kind='bar', title="Sales analysis for each month", ax=ax1,
    rot=0, alpha=0.5, color='brown').set(
    ylabel="Total sales amount in dollars", xlabel="Month")

# Set the format for xlabels
ax1.xaxis.set_major_formatter(FuncFormatter(lambda month_num, pos : cal.month_abbr[month_num + 1]))

# Sales anaysis per day of week.
product_sales_week = product_panel.groupby(
    product_panel.DATETIME.dt.dayofweek)['DOLLARS'].sum()
product_sales_week.plot(kind='bar', title="Sales analysis for day of week", ax=ax2,
    alpha=0.5, color='g', rot=0).set(ylabel="Total sales amount in dollars", xlabel="Day")

# Set the format for xlabels
ax2.xaxis.set_major_formatter(FuncFormatter(lambda day_num, pos : cal.day_abbr[day_num]))

# Sales analysis in each hour of a day.
product_sales_hour = product_panel.groupby(
    product_panel.DATETIME.dt.hour)['DOLLARS'].sum()
product_sales_hour.plot(kind='bar', title="Sales analysis in a day", ax=ax3,
    rot=0, alpha=0.5, color='blue').set(xlabel="Hour of Day",
    ylabel="Total sales amount in dollars");

# %% [markdown]
# Yogurt sales seem to be higehr closer towards the weekends and is higher during the afternoons.

# %% [markdown]
# ####Conclusion
#
# - We have a lot of NaNs in MINUTE, specifically from GR (67%) outlets. (not on code)
# - Yogurt sales before 2008 were dropped to maintain accuracy.
# - Yogurt sales seem to be higehr closer towards the weekends and is higher during the afternoons.
# - GK has the highest sales in yogurt

# %% [markdown]
# #Drug Data

# %%
df = pd.read_hdf(path, key='drug')

# %%
df.head()
# Out:
#    IRI_KEY  WEEK  SY  GE   VEND  ITEM  UNITS  DOLLARS     F  D  PR  \
# 0  8042577  1133   0   1  70470   300      2     1.78  NONE  0   0
# 1  8042577  1134   0   1  70470   300      1     0.89  NONE  0   0
# 2  8042577  1135   0   1  70470   300      1     0.89  NONE  0   0
# 3  8042577  1136   0   1  70470   313      1     0.89  NONE  0   0
# 4  8042577  1137   0   1  70470   300      2     1.78  NONE  0   0
#
#                     file  year_int
# 0  yogurt_drug_1114_1165         1
# 1  yogurt_drug_1114_1165         1
# 2  yogurt_drug_1114_1165         1
# 3  yogurt_drug_1114_1165         1
# 4  yogurt_drug_1114_1165         1

# %% [markdown]
# ####Missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 357688 entries, 0 to 29438
# Data columns (total 13 columns):
# IRI_KEY     357688 non-null int64
# WEEK        357688 non-null int64
# SY          357688 non-null int64
# GE          357688 non-null int64
# VEND        357688 non-null int64
# ITEM        357688 non-null int64
# UNITS       357688 non-null int64
# DOLLARS     357688 non-null float64
# F           357688 non-null object
# D           357688 non-null int64
# PR          357688 non-null int64
# file        357688 non-null object
# year_int    357688 non-null int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# There are no NaN in the dataset

# %% [markdown]
# ####Features

# %%
df[df['F']!='NONE'].groupby('F')['DOLLARS'].mean().plot(kind='bar', title='Average Sales by Feature');

# %% [markdown]
# Possible Values for Feature (F):
#
# - C – small ad, usually 1 line of text
# - B – medium size ad
# - A – large size ad
# - A+ ad – also known as “Q” or “R” – retailer coupon or rebate

# %% [markdown]
# ####Display

# %%
df[df['F']!='NONE'].groupby('D')['DOLLARS'].mean().plot(kind='bar', title='Average Sales by Display');

# %% [markdown]
# Possible values of Display(D):
#
# - 0 – NO
# - 1 – MINOR
# - 2 – MAJOR (MAJOR includes codes 1 & 2)
#
# Based on this, larger displays contribute to greater average sales.

# %% [markdown]
# ####Price Reduction

# %%
df[df['F']!='NONE'].groupby('PR')['DOLLARS'].mean().plot(kind='bar', title='Average Sales by Price Reduction');

# %% [markdown]
# Price Reduction flag:
#
# - 1 if TPR is 5% or greater
# - 0 otherwise
#
# Price Reduction has very little effect on sales.

# %% [markdown]
# ####Others
#
# System, Generator, Vendor and Item UPC were ignored as we do not have any documentation on them.

# %% [markdown]
# ####Statistical Significance Testing

# %%
def hyp_test(x1,x2, str1, str2):
    """2-tail 5% confidence interval if there is a difference"""
    p = ttest_ind(x1,x2)[1]
    if p<0.025:
        print str1+', '+str2+' reject null with ',p
    else:
        print str1+', '+str2+' fail'

print 'Features'
C=df[df['F']=='C']['DOLLARS']
vals = ['A+','A','B']
for val in vals:
    ad = df[df['F']==val]['DOLLARS']
    hyp_test(C,ad,'C',val)
print '\n'

print 'Displays'
C=df[df['D']==2]['DOLLARS']
vals = [0,1]
for val in vals:
    ad = df[df['D']==val]['DOLLARS']
    hyp_test(C,ad,'2',str(val))
print '\n'

print 'Price Reduction'
C=df[df['PR']==0]['DOLLARS']
vals = [1]
for val in vals:
    ad = df[df['PR']==val]['DOLLARS']*1.05
    hyp_test(C,ad,'2',str(val))
print '\n'
# Out:
# Features
# C, A+ reject null with  1.63634704551e-11
# C, A reject null with  0.000221408393697
# C, B reject null with  1.72750628502e-08
#
#
# Displays
# 2, 0 reject null with  0.0
# 2, 1 reject null with  5.46231451763e-35
#
#
# Price Reduction
# 2, 1 reject null with  0.0

# %% [markdown]
# ####Conclusion
#
# - Small ads (1 line of text) with larger displays and a 5% price reduction contributes to greater yogurt sales at drug stores.

# %% [markdown]
# ##Delivery Stores (with Drug)

# %%
store = pd.read_hdf(path, key='delivery_stores')

# %%
store.head()
# Out:
#    IRI_KEY  OU    EST_ACV        Market_Name  Open  Clsd  yearid  year name
# 0   200039  GR   9.602997  BUFFALO/ROCHESTER   539  1219       1  2001  107
# 1   200171  GR  28.454990          MILWAUKEE   522  9998       1  2001  118
# 2   200197  GR  11.314990  PEORIA/SPRINGFLD.   903  9998       1  2001   75
# 3   200233  GR   7.473000      OKLAHOMA CITY  1122  1150       1  2001  123
# 4   200272  GR  13.266000        LOS ANGELES   873  9998       1  2001  150

# %%
panel = pd.read_hdf(path, key='panel')

# %%
panel.head()
# Out:
#         COLUPC  DOLLARS  IRI_KEY  MINUTE OUTLET    PANID  UNITS  WEEK  \
# 0  17047000300     0.99  1097117  5068.0    DK   3138826    1.0  1514
# 1  17047000302     0.89  1097117  2224.0    DK   3138826    1.0  1489
# 2  17047000650     0.89  1097117  6551.0    DK   3138826    1.0  1488
# 3  17047000650     2.97  1097117  6177.0    DK   3182048    3.0  1526
# 4  17047001372     1.49  1097117   973.0    DK   3184911    1.0  1495
#
#                             file
# 0  yogurt_PANEL_DK_1479_1530.DAT
# 1  yogurt_PANEL_DK_1479_1530.DAT
# 2  yogurt_PANEL_DK_1479_1530.DAT
# 3  yogurt_PANEL_DK_1479_1530.DAT
# 4  yogurt_PANEL_DK_1479_1530.DAT

# %%
def get_datetime(week, minute):
    if np.isnan(minute):
        minute=0
    week, minute = int(week), int(minute)
    # Reference orginal date is September 3, 1979
    ref_orginal = dt.date.toordinal(dt.date(1979, 9, 3))
    # Convert minutes to days, hours, minutes
    days, hours, mins = (minute / 1440), ((minute % 1440) / 60), ((minute % 1440) % 60)
    # Convert from ordinal.
    return dt.datetime.fromordinal(ref_orginal + (week - 1) * 7 + days).replace(
        hour=hours, minute=mins)

week = panel['WEEK'].values
minute = panel['MINUTE'].values
datetime = []

for w,m in zip(week,minute):
    datetime.append(get_datetime(w,m))

panel = panel.drop(['MINUTE','WEEK'], axis=1)
panel['DATETIME']=datetime
panel['MONTH'] = panel.DATETIME.dt.month
panel['HOUR'] = panel.DATETIME.dt.hour
panel['year'] = panel.DATETIME.dt.year
panel = panel.drop(['DATETIME'], axis=1)

panel.head()
# Out:
#         COLUPC  DOLLARS  IRI_KEY OUTLET    PANID  UNITS  \
# 0  17047000300     0.99  1097117    DK   3138826    1.0
# 1  17047000302     0.89  1097117    DK   3138826    1.0
# 2  17047000650     0.89  1097117    DK   3138826    1.0
# 3  17047000650     2.97  1097117    DK   3182048    3.0
# 4  17047001372     1.49  1097117    DK   3184911    1.0
#
#                             file  MONTH  HOUR  year
# 0  yogurt_PANEL_DK_1479_1530.DAT      9    12  2008
# 1  yogurt_PANEL_DK_1479_1530.DAT      3    13  2008
# 2  yogurt_PANEL_DK_1479_1530.DAT      3    13  2008
# 3  yogurt_PANEL_DK_1479_1530.DAT     11     6  2008
# 4  yogurt_PANEL_DK_1479_1530.DAT      4    16  2008

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
panel.groupby('year')['DOLLARS'].mean().plot(kind='bar', title='Average Yogurt Sales');
plt.subplot(1,2,2)
panel.groupby('year')['DOLLARS'].sum().plot(kind='bar', title='Total Yogurt Sales');

# %%
store = store[['OU','EST_ACV','Market_Name','year','IRI_KEY']]
panel = panel[['DOLLARS','IRI_KEY','year']]
store_panel = store.merge(panel, how='inner')
store_panel.head()
# Out:
#    OU   EST_ACV Market_Name  year  IRI_KEY  DOLLARS
# 0  GR  19.26599  EAU CLAIRE  2001   200564     1.58
# 1  GR  19.26599  EAU CLAIRE  2001   200564     0.79
# 2  GR  19.26599  EAU CLAIRE  2001   200564     0.79
# 3  GR  19.26599  EAU CLAIRE  2001   200564     0.78
# 4  GR  19.26599  EAU CLAIRE  2001   200564     0.59

# %%
store_panel.groupby('Market_Name')['DOLLARS'].sum().plot(kind='bar', title='Sales');

# %%
plt.figure(figsize=(10,5))
for i in store_panel['Market_Name'].unique():
    cond = store_panel['Market_Name']==i
    store_panel[cond].groupby('year')['DOLLARS'].sum().plot(kind='line', title='Annual Sales')
plt.legend(store_panel['Market_Name'].unique(), loc=0);

# %% [markdown]
# Both stores have similar yogurt sales and both show decline after 2007.

# %%
drug = pd.read_hdf(path, key='drug')
drug.head()
# Out:
#    IRI_KEY  WEEK  SY  GE   VEND  ITEM  UNITS  DOLLARS     F  D  PR  \
# 0  8042577  1133   0   1  70470   300      2     1.78  NONE  0   0
# 1  8042577  1134   0   1  70470   300      1     0.89  NONE  0   0
# 2  8042577  1135   0   1  70470   300      1     0.89  NONE  0   0
# 3  8042577  1136   0   1  70470   313      1     0.89  NONE  0   0
# 4  8042577  1137   0   1  70470   300      2     1.78  NONE  0   0
#
#                     file  year_int
# 0  yogurt_drug_1114_1165         1
# 1  yogurt_drug_1114_1165         1
# 2  yogurt_drug_1114_1165         1
# 3  yogurt_drug_1114_1165         1
# 4  yogurt_drug_1114_1165         1

# %%
drug = drug[['IRI_KEY','F','D','PR']]
store_drug_panel = store_panel.merge(drug, how='inner')
store_drug_panel.head()
# Out:
#    OU   EST_ACV Market_Name  year  IRI_KEY  DOLLARS     F  D  PR
# 0  DR  5.167999  EAU CLAIRE  2001   651444     0.89  NONE  0   0
# 1  DR  5.167999  EAU CLAIRE  2001   651444     0.89  NONE  0   0
# 2  DR  5.167999  EAU CLAIRE  2001   651444     0.89  NONE  0   0
# 3  DR  5.167999  EAU CLAIRE  2001   651444     0.89  NONE  0   0
# 4  DR  5.167999  EAU CLAIRE  2001   651444     0.89  NONE  0   0

# %%
for i in store_drug_panel['Market_Name'].unique():
    plt.figure(figsize=(10,5))
    cond = store_drug_panel['Market_Name']==i
    store_drug_panel[cond].groupby(['F'])['DOLLARS'].mean().plot(kind='bar', title='Features of '+i)

# %% [markdown]
# EAU CLAIRE uses a varity of ad features

# %%
for i in store_drug_panel['Market_Name'].unique():
    plt.figure(figsize=(10,5))
    cond = store_drug_panel['Market_Name']==i
    store_drug_panel[cond].groupby(['D'])['DOLLARS'].mean().plot(kind='bar', title='Displays of '+i)

# %% [markdown]
# Both stores use simialr small displays

# %%
for i in store_drug_panel['Market_Name'].unique():
    plt.figure(figsize=(10,5))
    cond = store_drug_panel['Market_Name']==i
    store_drug_panel[cond].groupby(['PR'])['DOLLARS'].mean().plot(kind='bar', title='Public Relations of '+i)

# %% [markdown]
# Both stores have similar promotions of 5% discount

# %% [markdown]
# ###Conclusion
# All drug stores have similar yogurt sales strategies and similar sales patterns.

# %% [markdown]
# #Groc

# %%
store = pd.HDFStore(path)
nrows = store.get_storer('groc').nrows
r = np.random.randint(0,nrows,size=10000)
df=pd.read_hdf(path,'groc',where=pd.Index(r))
df.head()
# Out:
#           IRI_KEY  WEEK  SY  GE   VEND   ITEM  UNITS  DOLLARS     F  D  PR  \
# 8844382    232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 3824233   1104160  1371   0   1  70470    301     15    11.85  NONE  0   0
# 350301     264269  1314   0   1  21000  12041     16    10.17  NONE  0   0
# 2713461    235834  1637  88   3  99998  16114     29    14.50  NONE  0   0
# 11287831   680725  1329   0   1  52159   1360     12    23.88     A  0   1
#
#                            file  year_int
# 8844382   yogurt_groc_1218_1269         3
# 3824233   yogurt_groc_1322_1373         5
# 350301    yogurt_groc_1270_1321         4
# 2713461   yogurt_groc_1635_1686        11
# 11287831  yogurt_groc_1322_1373         5

# %% [markdown]
# ####Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 8844382 to 9528840
# Data columns (total 13 columns):
# IRI_KEY     10000 non-null int64
# WEEK        10000 non-null int64
# SY          10000 non-null int64
# GE          10000 non-null int64
# VEND        10000 non-null int64
# ITEM        10000 non-null int64
# UNITS       10000 non-null int64
# DOLLARS     10000 non-null float64
# F           10000 non-null object
# D           10000 non-null int64
# PR          10000 non-null int64
# file        10000 non-null object
# year_int    10000 non-null int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# ####Features

# %%
df[df['F']!='NONE'].groupby('F')['DOLLARS'].mean().plot(kind='bar', title='Average Sales by Feature');

# %%
def hyp_test(x1,x2, str1, str2):
    """2-tail 5% confidence interval if there is a difference"""
    p = ttest_ind(x1,x2)[1]
    if p<0.025:
        print str1+', '+str2+' reject null with ',p
    else:
        print str1+', '+str2+' fail'

# %%
print 'Features'
C=df[df['F']=='A+']['DOLLARS']
vals = ['C','A','B']
for val in vals:
    ad = df[df['F']==val]['DOLLARS']
    hyp_test(C,ad,'A+',val)
print '\n'
# Out:
# Features
# A+, C fail
# A+, A fail
# A+, B fail

# %% [markdown]
# Features have no affect on sales.

# %% [markdown]
# ####Displays

# %%
df[df['F']!='NONE'].groupby('D')['DOLLARS'].mean().plot(kind='bar', title='Average Sales by Display');

# %%
print 'Displays'
C=df[df['D']==1]['DOLLARS']
vals = [0,2]
for val in vals:
    ad = df[df['D']==val]['DOLLARS']
    hyp_test(C,ad,'2',str(val))
print '\n'
# Out:
# Displays
# 2, 0 reject null with  1.52189827744e-16
# 2, 2 fail

# %% [markdown]
# Having any display improves sales

# %% [markdown]
# ####Price Reduction

# %%
df[df['F']!='NONE'].groupby('PR')['DOLLARS'].mean().plot(kind='bar', title='Average Sales by Price Reduction');

# %%
print 'Price Reduction'
C=df[df['PR']==0]['DOLLARS']
vals = [1]
for val in vals:
    ad = df[df['PR']==val]['DOLLARS']*1.05
    hyp_test(C,ad,'2',str(val))
print '\n'
# Out:
# Price Reduction
# 2, 1 reject null with  4.00525831947e-41

# %% [markdown]
# Price reduction has a significant impact on sales

# %% [markdown]
# ####Conclusion

# %% [markdown]
# Price reduction and some form of advertising display improves sales

# %%
new_df = df.merge(store)
# Out:
#        IRI_KEY  WEEK  SY  GE   VEND   ITEM  UNITS  DOLLARS     F  D  PR  \
# 0       232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 1       232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 2       232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 3       232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 4       232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 5       232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 6       232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 7       232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 8       232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 9       232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 10      232473  1257   0   1  70470    636     62    31.00  NONE  0   1
# 11      232473  1315   0   1  75270    166     10    22.90  NONE  0   1
# 12      232473  1315   0   1  75270    166     10    22.90  NONE  0   1
# 13      232473  1315   0   1  75270    166     10    22.90  NONE  0   1
# 14      232473  1315   0   1  75270    166     10    22.90  NONE  0   1
# 15      232473  1315   0   1  75270    166     10    22.90  NONE  0   1
# 16      232473  1315   0   1  75270    166     10    22.90  NONE  0   1
# 17      232473  1315   0   1  75270    166     10    22.90  NONE  0   1
# 18      232473  1315   0   1  75270    166     10    22.90  NONE  0   1
# 19      232473  1315   0   1  75270    166     10    22.90  NONE  0   1
# 20      232473  1315   0   1  75270    166     10    22.90  NONE  0   1
# 21      232473  1315   0   1  75270    166     10    22.90  NONE  0   1
# 22      232473  1685   0   2  36632   3576      2    13.98  NONE  0   0
# 23      232473  1685   0   2  36632   3576      2    13.98  NONE  0   0
# 24      232473  1685   0   2  36632   3576      2    13.98  NONE  0   0
# 25      232473  1685   0   2  36632   3576      2    13.98  NONE  0   0
# 26      232473  1685   0   2  36632   3576      2    13.98  NONE  0   0
# 27      232473  1685   0   2  36632   3576      2    13.98  NONE  0   0
# 28      232473  1685   0   2  36632   3576      2    13.98  NONE  0   0
# 29      232473  1685   0   2  36632   3576      2    13.98  NONE  0   0
# ...        ...   ...  ..  ..    ...    ...    ...      ...   ... ..  ..
# 90399   253739  1477  88   4  99998  38525      5     2.50  NONE  0   1
# 90400   253739  1477  88   4  99998  38525      5     2.50  NONE  0   1
# 90401   253739  1477  88   4  99998  38525      5     2.50  NONE  0   1
# 90402   644492  1180   0   1  21000  12069      9     4.50  NONE  0   0
# 90403   644492  1180   0   1  21000  12069      9     4.50  NONE  0   0
# 90404   644492  1180   0   1  21000  12069      9     4.50  NONE  0   0
# 90405   644492  1180   0   1  21000  12069      9     4.50  NONE  0   0
# 90406   266117  1154   0   3  36632    550      2     4.00  NONE  0   0
# 90407   266117  1154   0   3  36632    550      2     4.00  NONE  0   0
# 90408   655064  1229   0   2  21000  12643     16    11.04  NONE  0   0
# 90409   655064  1229   0   2  21000  12643     16    11.04  NONE  0   0
# 90410   655064  1229   0   2  21000  12643     16    11.04  NONE  0   0
# 90411   282496  1117   0   1  36632    109     15    11.25  NONE  0   1
# 90412   293111  1126   0   1  21000  12043      3     1.65  NONE  0   0
# 90413   293111  1126   0   1  21000  12043      3     1.65  NONE  0   0
# 90414   293111  1126   0   1  21000  12043      3     1.65  NONE  0   0
# 90415   293111  1126   0   1  21000  12043      3     1.65  NONE  0   0
# 90416   293111  1126   0   1  21000  12043      3     1.65  NONE  0   0
# 90417   229831  1144   0   1  70470    655      5     3.95  NONE  0   0
# 90418   229831  1144   0   1  70470    655      5     3.95  NONE  0   0
# 90419   229831  1144   0   1  70470    655      5     3.95  NONE  0   0
# 90420   239849  1466   0   1  70470    323     16     9.44  NONE  0   0
# 90421   239849  1466   0   1  70470    323     16     9.44  NONE  0   0
# 90422   239849  1466   0   1  70470    323     16     9.44  NONE  0   0
# 90423   239849  1466   0   1  70470    323     16     9.44  NONE  0   0
# 90424   239849  1466   0   1  70470    323     16     9.44  NONE  0   0
# 90425   273608  1246   0   1  70470    650      2     1.20  NONE  0   1
# 90426   273608  1246   0   1  70470    650      2     1.20  NONE  0   1
# 90427   273608  1246   0   1  70470    650      2     1.20  NONE  0   1
# 90428   273608  1246   0   1  70470    650      2     1.20  NONE  0   1
#
#                         file  year_int  OU    EST_ACV     Market_Name  year
# 0      yogurt_groc_1218_1269         3  GR  24.080990     LOS ANGELES  2001
# 1      yogurt_groc_1218_1269         3  GR  28.218990     LOS ANGELES  2010
# 2      yogurt_groc_1218_1269         3  GR  28.218990     LOS ANGELES  2011
# 3      yogurt_groc_1218_1269         3  GR  24.901990     LOS ANGELES  2002
# 4      yogurt_groc_1218_1269         3  GR  24.901990     LOS ANGELES  2003
# 5      yogurt_groc_1218_1269         3  GR  26.452990     LOS ANGELES  2004
# 6      yogurt_groc_1218_1269         3  GR  26.452990     LOS ANGELES  2005
# 7      yogurt_groc_1218_1269         3  GR  26.355990     LOS ANGELES  2006
# 8      yogurt_groc_1218_1269         3  GR  26.942990     LOS ANGELES  2007
# 9      yogurt_groc_1218_1269         3  GR  28.140990     LOS ANGELES  2008
# 10     yogurt_groc_1218_1269         3  GR  28.198990     LOS ANGELES  2009
# 11     yogurt_groc_1270_1321         4  GR  24.080990     LOS ANGELES  2001
# 12     yogurt_groc_1270_1321         4  GR  28.218990     LOS ANGELES  2010
# 13     yogurt_groc_1270_1321         4  GR  28.218990     LOS ANGELES  2011
# 14     yogurt_groc_1270_1321         4  GR  24.901990     LOS ANGELES  2002
# 15     yogurt_groc_1270_1321         4  GR  24.901990     LOS ANGELES  2003
# 16     yogurt_groc_1270_1321         4  GR  26.452990     LOS ANGELES  2004
# 17     yogurt_groc_1270_1321         4  GR  26.452990     LOS ANGELES  2005
# 18     yogurt_groc_1270_1321         4  GR  26.355990     LOS ANGELES  2006
# 19     yogurt_groc_1270_1321         4  GR  26.942990     LOS ANGELES  2007
# 20     yogurt_groc_1270_1321         4  GR  28.140990     LOS ANGELES  2008
# 21     yogurt_groc_1270_1321         4  GR  28.198990     LOS ANGELES  2009
# 22     yogurt_groc_1635_1686        11  GR  24.080990     LOS ANGELES  2001
# 23     yogurt_groc_1635_1686        11  GR  28.218990     LOS ANGELES  2010
# 24     yogurt_groc_1635_1686        11  GR  28.218990     LOS ANGELES  2011
# 25     yogurt_groc_1635_1686        11  GR  24.901990     LOS ANGELES  2002
# 26     yogurt_groc_1635_1686        11  GR  24.901990     LOS ANGELES  2003
# 27     yogurt_groc_1635_1686        11  GR  26.452990     LOS ANGELES  2004
# 28     yogurt_groc_1635_1686        11  GR  26.452990     LOS ANGELES  2005
# 29     yogurt_groc_1635_1686        11  GR  26.355990     LOS ANGELES  2006
# ...                      ...       ...  ..        ...             ...   ...
# 90399  yogurt_groc_1427_1478         7  GR   7.053997  RALEIGH/DURHAM  2006
# 90400  yogurt_groc_1427_1478         7  GR  14.704990  RALEIGH/DURHAM  2007
# 90401  yogurt_groc_1427_1478         7  GR  13.563000  RALEIGH/DURHAM  2008
# 90402  yogurt_groc_1166_1217         2  GR   4.600998      DALLAS, TX  2001
# 90403  yogurt_groc_1166_1217         2  GR   4.546997      DALLAS, TX  2002
# 90404  yogurt_groc_1166_1217         2  GR   4.546997      DALLAS, TX  2003
# 90405  yogurt_groc_1166_1217         2  GR   4.955997      DALLAS, TX  2004
# 90406  yogurt_groc_1114_1165         1  GR  19.265990  SOUTH CAROLINA  2001
# 90407  yogurt_groc_1114_1165         1  GR  19.726990  SOUTH CAROLINA  2002
# 90408  yogurt_groc_1218_1269         3  GR  24.657000       CHARLOTTE  2001
# 90409  yogurt_groc_1218_1269         3  GR  23.864990       CHARLOTTE  2002
# 90410  yogurt_groc_1218_1269         3  GR  23.864990       CHARLOTTE  2003
# 90411  yogurt_groc_1114_1165         1  GR  21.595990    PHILADELPHIA  2001
# 90412  yogurt_groc_1114_1165         1  GR  12.845990     MISSISSIPPI  2001
# 90413  yogurt_groc_1114_1165         1  GR  13.264000     MISSISSIPPI  2002
# 90414  yogurt_groc_1114_1165         1  GR  13.264000     MISSISSIPPI  2003
# 90415  yogurt_groc_1114_1165         1  GR  12.801990     MISSISSIPPI  2004
# 90416  yogurt_groc_1114_1165         1  GR  12.801990     MISSISSIPPI  2005
# 90417  yogurt_groc_1114_1165         1  GR  18.651990      SACRAMENTO  2001
# 90418  yogurt_groc_1114_1165         1  GR  18.909000      SACRAMENTO  2002
# 90419  yogurt_groc_1114_1165         1  GR  18.909000      SACRAMENTO  2003
# 90420  yogurt_groc_1427_1478         7  GR  13.644000     PHOENIX, AZ  2010
# 90421  yogurt_groc_1427_1478         7  GR  13.644000     PHOENIX, AZ  2011
# 90422  yogurt_groc_1427_1478         7  GR  16.443980     PHOENIX, AZ  2007
# 90423  yogurt_groc_1427_1478         7  GR  13.509000     PHOENIX, AZ  2008
# 90424  yogurt_groc_1427_1478         7  GR  13.545000     PHOENIX, AZ  2009
# 90425  yogurt_groc_1218_1269         3  GR  19.890000  RALEIGH/DURHAM  2001
# 90426  yogurt_groc_1218_1269         3  GR  19.879000  RALEIGH/DURHAM  2002
# 90427  yogurt_groc_1218_1269         3  GR  19.879000  RALEIGH/DURHAM  2003
# 90428  yogurt_groc_1218_1269         3  GR  20.493990  RALEIGH/DURHAM  2004
#
# [90429 rows x 17 columns]
